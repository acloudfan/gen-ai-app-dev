# %% [markdown]
# # ML Functions

# %%
# pip install matplotlib

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 1. Sigmoid
#
# ## The sigmoid function has a characteristic "S"-shaped curve
# * which is why it is called the sigmoid function
# * Varies between 0 & 1
# * Further from the origin, derivative (i.e., slope) is almost 0
# *

# %%
def sigmoid(x):
    """
    Calculates the sigmoid function and its derivative.

    Args:
        x (ndarray): Input array.

    Returns:
        ndarray: Sigmoid function and its derivative.
    """
    s = 1 / (1 + np.exp(-x))
    ds = s * (1 - s)
    return s, ds

x = np.arange(-6, 6, 0.01)
s, ds = sigmoid(x)

# Setup centered axes
fig, ax = plt.subplots(figsize=(9, 5))
ax.spines['left'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# Create and show plot
ax.plot(x, s, color="#307EC7", linewidth=3, label="sigmoid")
ax.plot(x, ds, color="#9621E2", linewidth=3, label="derivative")
ax.legend(loc="upper left", frameon=False)
plt.title("Sigmoid Function and Its Derivative")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.show()

# %% [markdown]
# ## 2. Tanh (a.k.a. Hyperbolic Tangent)
#
# Similar to **Sigmoid** but varies between -1 and 1

# %%
def tanh(x):
    """
    Calculates the tanh function.

    Args:
        x (ndarray): Input array.

    Returns:
        ndarray: tanh function
    """
    t = (2 / (1 + np.exp(-2*x)))-1
    
    return t

fig, ax = plt.subplots(figsize=(9, 5))
ax.spines['left'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')




x = np.arange(-5, 5, 0.01)
y = tanh(x)

ax.plot(x, y, color="#307EC7", linewidth=3, label="tanh")
plt.title("Tanh function")
ax.legend(loc="upper left", frameon=False)

# %% [markdown]
# # 3. Softmax

# %%
def softmax(x):
    """
    Calculates the softmax function.

    Args:
        x (ndarray): Input array.

    Returns:
        ndarray: tanh function
    """
    t = (2 / (1 + np.exp(-2*x)))-1
    
    z = np.exp(x) / np.sum(np.exp(x))
    
    
    return z


fig, ax = plt.subplots(figsize=(9, 5))
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')




x = np.arange(-5, 5, 0.01)
y = softmax(x)

ax.plot(x, y, color="#307EC7", linewidth=3, label="Softmax")
plt.title("Softmax function")
ax.legend(loc="upper left", frameon=False)

# %% [markdown]
# # 4. ReLU
# Rectified Linear Unit

# %%
def RelU(x):
    """
    Calculates the ReLU function and its derivative.

    Args:
        x (ndarray): Input array.

    Returns:
        ndarray: ReLU function and its derivative.
    """
    s = max(0,x)
    if s > 0 :
        ds = 1
    else:
        ds = 0

    return s, ds

# %%
series_in = np.arange(-6, 6, 0.01)
s, ds = RelU(x)

series_out, series_out_ds = [ReLU(x) for x in series_in]

# Setup centered axes
fig, ax = plt.subplots(figsize=(9, 5))
ax.spines['left'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# Create and show plot
ax.plot(x, s, color="#307EC7", linewidth=3, label="sigmoid")
ax.plot(x, ds, color="#9621E2", linewidth=3, label="derivative")
ax.legend(loc="upper left", frameon=False)
plt.title("Sigmoid Function and Its Derivative")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 series_in = np.arange(-6, 6, 0.01)
# ----> 2 s, ds = RelU(x)
#       4 series_out, series_out_ds = [ReLU(x) for x in series_in]
#       6 # Setup centered axes
#
# Cell In[5], line 11, in RelU(x)
#       1 def RelU(x):
#       2     """
#       3     Calculates the ReLU function and its derivative.
#       4
#    (...)
#       9         ndarray: ReLU function and its derivative.
#      10     """
# ---> 11     s = max(0,x)
#      12     if s > 0 :
#      13         ds = 1
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
