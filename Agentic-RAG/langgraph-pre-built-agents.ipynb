# %% [markdown]
# # Pre-built agents
#
# https://langchain-ai.github.io/langgraph/how-tos/create-react-agent/#code

# %%
from langgraph.prebuilt import create_react_agent

tools = []
graph = create_react_agent(model, tools=tools)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 4
#       1 from langgraph.prebuilt import create_react_agent
#       3 tools = []
# ----> 4 graph = create_react_agent(model, tools=tools)
#
# File ~\anaconda3\envs\genai-course\Lib\site-packages\langgraph\prebuilt\chat_agent_executor.py:411, in create_react_agent(model, tools, messages_modifier, checkpointer, interrupt_before, interrupt_after, debug)
#     409 else:
#     410     tool_classes = tools
# --> 411 model = model.bind_tools(tool_classes)
#     413 # Define the function that determines whether to continue or not
#     414 def should_continue(state: AgentState):
#
# AttributeError: 'dict' object has no attribute 'bind_tools'
